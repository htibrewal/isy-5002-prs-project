# %%
import pandas as pd

df = pd.read_csv('HDBCarparkInformation.csv')

# %%
df.head(5)
# Out:
#   car_park_no                                      address     x_coord  \
# 0         ACB  BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK  30314.7936
# 1         ACM                    BLK 98A ALJUNIED CRESCENT  33758.4143
# 2         AH1                          BLK 101 JALAN DUSUN  29257.7203
# 3        AK19               BLOCK 253 ANG MO KIO STREET 21  28185.4359
# 4        AK31             BLK 302/348 ANG MO KIO STREET 31  29482.0290
#
#       y_coord          car_park_type type_of_parking_system  \
# 0  31490.4942      BASEMENT CAR PARK     ELECTRONIC PARKING
# 1  33695.5198  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2  34500.3599       SURFACE CAR PARK     ELECTRONIC PARKING
# 3  39012.6664       SURFACE CAR PARK         COUPON PARKING
# 4  38684.1754       SURFACE CAR PARK         COUPON PARKING
#
#   short_term_parking             free_parking night_parking  car_park_decks  \
# 0          WHOLE DAY                       NO           YES               1
# 1          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES               5
# 2          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES               0
# 3            7AM-7PM                       NO            NO               0
# 4                 NO                       NO            NO               0
#
#    gantry_height car_park_basement
# 0            1.8                 Y
# 1            2.1                 N
# 2            0.0                 N
# 3            0.0                 N
# 4            0.0                 N

# %%
df.isnull().sum()
# Out:
# car_park_no               0
# address                   0
# x_coord                   0
# y_coord                   0
# car_park_type             0
# type_of_parking_system    0
# short_term_parking        0
# free_parking              0
# night_parking             0
# car_park_decks            0
# gantry_height             0
# car_park_basement         0
# dtype: int64

# %%
df.shape
# Out:
# (2243, 12)

# %%
# Import necessary libraries
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Sample data (replace this with your actual DataFrame)
data = df

# Step 1: Prompt user input for gantry height and car park type
min_height = float(input("Enter the minimum gantry height: "))
car_park_type = input("Enter the type of car park (e.g., SURFACE CAR PARK, MULTI-STOREY CAR PARK): ").upper()

# Step 2: Set default for 'free_parking' to "YES" unless explicitly "NO"
data['free_parking'] = data['free_parking'].apply(lambda x: 'NO' if x == 'NO' else 'YES')

# Step 3: Filter data based on user input
filtered_data = data[(data['gantry_height'] >= min_height) &
                     (data['car_park_type'] == car_park_type)]

# Step 4: Convert 'free_parking' to binary (0 for NO, 1 for YES)
filtered_data['free_parking_binary'] = filtered_data['free_parking'].map({'NO': 0, 'YES': 1})

# Step 5: Select features for clustering (e.g., x_coord, y_coord, free_parking_binary)
clustering_data = filtered_data[['x_coord', 'y_coord', 'free_parking_binary']]

# Step 6: Normalize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(clustering_data)

# Step 7: Perform hierarchical clustering
linked = linkage(scaled_data, method='ward')

# Step 8: Plot dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked, labels=filtered_data['car_park_no'].values, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Dendrogram for Car Park Clustering')
plt.xlabel('Car Park Number')
plt.ylabel('Euclidean Distance')
plt.show()


# Define the maximum distance for clusters or specify number of clusters
max_distance = 3  # Adjust this value based on the dendrogram to control the number of clusters

# Step 9: Create cluster labels
cluster_labels = fcluster(linked, max_distance, criterion='distance')

# Add cluster labels to the filtered data
filtered_data['cluster'] = cluster_labels

# Display sample data from each cluster
for cluster_id in filtered_data['cluster'].unique():
    print(f"\nCluster {cluster_id}:")
    display(filtered_data[filtered_data['cluster'] == cluster_id][['car_park_no', 'x_coord', 'y_coord', 'free_parking', 'cluster']].head())
# Out:
# Enter the minimum gantry height: 1.8
# Enter the type of car park (e.g., SURFACE CAR PARK, MULTI-STOREY CAR PARK): SURFACE CAR PARK
# <ipython-input-7-ddac67ff8c66>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['free_parking_binary'] = filtered_data['free_parking'].map({'NO': 0, 'YES': 1})
# Cluster 5:
# <ipython-input-7-ddac67ff8c66>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['cluster'] = cluster_labels
#     car_park_no     x_coord     y_coord free_parking  cluster
# 23         AR1L  22359.0217  31801.6379           NO        5
# 31          AV1  24649.7520  29778.7266           NO        5
# 277        BM14  25276.6255  30161.1078           NO        5
# 279         BM2  25399.6152  29918.9512           NO        5
# 281        BM26  25118.4593  29967.6925           NO        5
# Cluster 13:
#    car_park_no     x_coord     y_coord free_parking  cluster
# 36         A11  28541.1400  38785.3600          YES       13
# 38         A13  28388.5100  38892.0300          YES       13
# 41         A20  29684.7366  38554.0251          YES       13
# 42         A21  29446.1477  38906.1139          YES       13
# 45         A25  30037.5660  38313.6296          YES       13
# Cluster 4:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 54          A33  28152.8391  39115.4784           NO        4
# 72          A51  28117.6053  39054.6321           NO        4
# 74         A52L  29426.2389  39033.6150           NO        4
# 138        BE12  29963.6285  36903.1662           NO        4
# 163        BE36  29248.3008  37730.4375           NO        4
# Cluster 16:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 136        BE10  30223.1994  36651.8815          YES       16
# 137        BE11  30194.9243  36877.2792          YES       16
# 143        BE18  27751.5586  37825.0781          YES       16
# 147        BE22  29818.0559  36839.3645          YES       16
# 149        BE24  29576.3203  37491.2812          YES       16
# Cluster 7:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 179        BJAL  20505.1610  41097.6794          YES        7
# 180        BJBL  20272.3997  40658.5045          YES        7
# 183        BJ10  21026.3461  40101.7077          YES        7
# 191        BJ18  20743.2768  40326.2581          YES        7
# 192        BJ19  20773.5976  40665.0357          YES        7
# Cluster 1:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 250        BKE2  30466.3496  32935.1367           NO        1
# 251        BKE3  30502.0605  32966.8867           NO        1
# 316         BR8  30363.7715  34154.9883           NO        1
# 528         CR1  31337.5185  31734.6056           NO        1
# 534        CR30  30406.3770  32213.3125           NO        1
# Cluster 8:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 257        BL10  14434.5806  36212.2117          YES        8
# 258        BL13  14836.3467  36315.1094          YES        8
# 268         BL3  14190.8096  36556.4297          YES        8
# 269         BL8  14653.3598  36396.1197          YES        8
# 271         BL9  14356.1152  36445.4219          YES        8
# Cluster 6:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 270        BL8L  14505.6710  36484.5266           NO        6
# 548         C11  20522.6462  33009.6141           NO        6
# 553         C16  20116.5191  32955.7857           NO        6
# 555         C18  20215.8784  32729.9597           NO        6
# 559         C20  20425.9232  32848.9500           NO        6
# Cluster 9:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 274        BM10  25857.7754  30056.6386          YES        9
# 275        BM12  25769.3044  30009.7592          YES        9
# 293         BM9  25889.8506  30167.4343          YES        9
# 294         BP1  27059.7441  28364.7207          YES        9
# 295         BP2  27297.2734  28508.1074          YES        9
# Cluster 15:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 309        BR14  30967.5336  34242.9719          YES       15
# 314         BR5  30768.0099  34127.2333          YES       15
# 529        CR1A  31521.2359  31781.8809          YES       15
# 530        CR1B  31565.7734  31819.2245          YES       15
# 532        CR29  30612.5155  32012.4666          YES       15
# Cluster 11:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 323         B10  39172.2903  34582.9441          YES       11
# 325         B11  38803.7496  34507.0389          YES       11
# 326         B12  38523.5625  34424.8004          YES       11
# 327         B13  38733.3633  34652.0234          YES       11
# 328         B14  38920.4797  34597.3930          YES       11
# Cluster 2:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 336         B24  39682.7466  34983.1176           NO        2
# 338         B25  39927.1063  35018.7287           NO        2
# 355         B45  38250.9386  34876.1148           NO        2
# 370          B6  38797.4548  34284.6160           NO        2
# 382          B7  38973.5423  34152.0151           NO        2
# Cluster 20:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 444         CKT2  17986.1193  40839.8157           NO       20
# 506         CK65  18064.0069  41548.1433           NO       20
# 1105        PDP5  20516.3308  40817.8945           NO       20
# 1372        SB34  25796.9155  48472.7851           NO       20
# 2007        W100  23428.6148  45604.4370           NO       20
# Cluster 3:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 544          CV3  45045.6516  41323.3393           NO        3
# 1252        PR12  41283.8272  38971.2519           NO        3
# 1253        PR13  40942.8203  39055.5703           NO        3
# 1254        PR14  41151.3750  38747.0430           NO        3
# 1256         PR3  41064.8727  39231.0631           NO        3
# Cluster 10:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 547         C10  20837.8461  33414.5726          YES       10
# 549         C12  20519.9139  33782.4237          YES       10
# 564         C24  21096.4707  34048.6484          YES       10
# 565         C25  20840.7482  33844.4911          YES       10
# 566         C26  20945.3775  33870.6421          YES       10
# Cluster 14:
#     car_park_no     x_coord     y_coord free_parking  cluster
# 664         HG1  34773.1311  38246.9455          YES       14
# 675        HG14  35023.2798  39024.5479          YES       14
# 678        HG17  34080.7076  37750.4416          YES       14
# 679        HG18  34191.1758  37792.5508          YES       14
# 680        HG19  33618.2651  37216.3433          YES       14
# Cluster 19:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 1140        PL33  36521.4363  42569.3563           NO       19
# 1151        PL44  35568.6186  42304.0762           NO       19
# 1571        SK97  33889.5864  41641.0117           NO       19
# 2147         Y13  28505.9395  45881.9889           NO       19
# 2170         Y29  28135.4160  44332.6484           NO       19
# Cluster 12:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 1249         PR1  41875.5357  38818.4836          YES       12
# 1251        PR11  42030.2409  39606.4261          YES       12
# 1255         PR2  41590.9705  38812.1621          YES       12
# 1258         PR5  41554.7014  39169.7008          YES       12
# 1463         SI1  41132.0547  35918.9005          YES       12
# Cluster 17:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 2006         W10  21545.6709  46781.8077          YES       17
# 2023         W17  22249.7662  46486.5748          YES       17
# 2024         W18  22115.7552  46747.5940          YES       17
# 2029         W19  21755.7880  46587.4955          YES       17
# 2030         W20  21482.2371  46304.8149          YES       17
# Cluster 18:
#      car_park_no     x_coord     y_coord free_parking  cluster
# 2145         Y11  27625.6289  45280.5234          YES       18
# 2148         Y14  28260.7012  46043.2891          YES       18
# 2149        Y14A  28246.3185  46249.5229          YES       18
# 2150         Y15  28389.0234  46261.6211          YES       18
# 2151         Y16  28681.0314  46086.2424          YES       18

# %%
q
